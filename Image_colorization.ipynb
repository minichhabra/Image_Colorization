# %%
from keras.layers import Conv2D, UpSampling2D, InputLayer, Conv2DTranspose
from keras.layers import Activation, Dense, Dropout, Flatten
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb, rgb2gray, xyz2lab
from skimage.io import imsave
import numpy as np
import os
import random
import tensorflow as tf

# %%
# Get images
image = img_to_array(load_img('woman1.png'))
print(image.shape)
image = np.array(image, dtype=float)
# Out:
# (400, 400, 3)

# %%
import cv2
X = rgb2lab(1.0/255*image)[:,:,0]
Y = rgb2lab(1.0/255*image)[:,:,1:]
Y /= 128
#print(X)
#print(Y)
#cap.release()
cv2.waitKey(0)
cv2.destroyAllWindows()
X = X.reshape(1, 400, 400, 1)
Y = Y.reshape(1, 400, 400, 2)

# %%
# Building the neural network
model = Sequential()
model.add(InputLayer(input_shape=(None, None, 1)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', strides=2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', strides=2))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(2, (3, 3), activation='tanh', padding='same'))

# %%
# Finish model
model.compile(optimizer='rmsprop',loss='mse')

# %%
model.fit(x=X, 
    y=Y,
    batch_size=1,
    epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 195ms/step - loss: 0.0017
# Epoch 2/100
# 1/1 [==============================] - 0s 199ms/step - loss: 0.0016
# Epoch 3/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0017
# Epoch 4/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0021
# Epoch 5/100
# 1/1 [==============================] - 0s 223ms/step - loss: 0.0028
# Epoch 6/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0020
# Epoch 7/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0021
# Epoch 8/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0027
# Epoch 9/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0030
# Epoch 10/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0021
# Epoch 11/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0017
# Epoch 12/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0016
# Epoch 13/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0016
# Epoch 14/100
# 1/1 [==============================] - 0s 201ms/step - loss: 0.0019
# Epoch 15/100
# 1/1 [==============================] - 0s 208ms/step - loss: 0.0020
# Epoch 16/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0019
# Epoch 17/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0021
# Epoch 18/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0017
# Epoch 19/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0017
# Epoch 20/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.0016
# Epoch 21/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.0020
# Epoch 22/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0016
# Epoch 23/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0014
# Epoch 24/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0014
# Epoch 25/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0019
# Epoch 26/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0027
# Epoch 27/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0015
# Epoch 28/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0014
# Epoch 29/100
# 1/1 [==============================] - 0s 180ms/step - loss: 0.0014
# Epoch 30/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0017
# Epoch 31/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0020
# Epoch 32/100
# 1/1 [==============================] - 0s 198ms/step - loss: 0.0022
# Epoch 33/100
# 1/1 [==============================] - 0s 209ms/step - loss: 0.0018
# Epoch 34/100
# 1/1 [==============================] - 0s 190ms/step - loss: 0.0025
# Epoch 35/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0019
# Epoch 36/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0015
# Epoch 37/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0016
# Epoch 38/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0016
# Epoch 39/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0015
# Epoch 40/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0014
# Epoch 41/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0018
# Epoch 42/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0014
# Epoch 43/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0013
# Epoch 44/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0013
# Epoch 45/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0016
# Epoch 46/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0014
# Epoch 47/100
# 1/1 [==============================] - 0s 179ms/step - loss: 0.0019
# Epoch 48/100
# 1/1 [==============================] - 0s 183ms/step - loss: 0.0024
# Epoch 49/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0033
# Epoch 50/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0018
# Epoch 51/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0013
# Epoch 52/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0012
# Epoch 53/100
# 1/1 [==============================] - 0s 193ms/step - loss: 0.0013
# Epoch 54/100
# 1/1 [==============================] - 0s 184ms/step - loss: 0.0020
# Epoch 55/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0019
# Epoch 56/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0018
# Epoch 57/100
# 1/1 [==============================] - 0s 175ms/step - loss: 0.0014
# Epoch 58/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0012
# Epoch 59/100
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0011
# Epoch 60/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0012
# Epoch 61/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0013
# Epoch 62/100
# 1/1 [==============================] - 0s 189ms/step - loss: 0.0014
# Epoch 63/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.0014
# Epoch 64/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0014
# Epoch 65/100
# 1/1 [==============================] - 0s 170ms/step - loss: 0.0012
# Epoch 66/100
# 1/1 [==============================] - 0s 174ms/step - loss: 0.0015
# Epoch 67/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0016
# Epoch 68/100
# 1/1 [==============================] - 0s 196ms/step - loss: 0.0021
# Epoch 69/100
# 1/1 [==============================] - 0s 202ms/step - loss: 0.0013
# Epoch 70/100
# 1/1 [==============================] - 0s 169ms/step - loss: 0.0012
# Epoch 71/100
# 1/1 [==============================] - 0s 181ms/step - loss: 0.0014
# Epoch 72/100
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0016
# Epoch 73/100
# 1/1 [==============================] - 0s 168ms/step - loss: 0.0014
# Epoch 74/100
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0013
# Epoch 75/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0013
# Epoch 76/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.0011
# Epoch 77/100
# 1/1 [==============================] - 0s 173ms/step - loss: 0.0011
# Epoch 78/100
# 1/1 [==============================] - 0s 214ms/step - loss: 0.0012
# Epoch 79/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0012
# Epoch 80/100
# 1/1 [==============================] - 0s 172ms/step - loss: 0.0014
# Epoch 81/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0019
# Epoch 82/100
# 1/1 [==============================] - 0s 182ms/step - loss: 0.0020
# Epoch 83/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0014
# Epoch 84/100
# 1/1 [==============================] - 0s 194ms/step - loss: 0.0011
# Epoch 85/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0013
# Epoch 86/100
# 1/1 [==============================] - 0s 191ms/step - loss: 0.0014
# Epoch 87/100
# 1/1 [==============================] - 0s 210ms/step - loss: 0.0013
# Epoch 88/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0014
# Epoch 89/100
# 1/1 [==============================] - 0s 178ms/step - loss: 0.0011
# Epoch 90/100
# 1/1 [==============================] - 0s 197ms/step - loss: 0.0012
# Epoch 91/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0016
# Epoch 92/100
# 1/1 [==============================] - 0s 176ms/step - loss: 0.0016
# Epoch 93/100
# 1/1 [==============================] - 0s 188ms/step - loss: 0.0014
# Epoch 94/100
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0013
# Epoch 95/100
# 1/1 [==============================] - 0s 192ms/step - loss: 0.0013
# Epoch 96/100
# 1/1 [==============================] - 0s 187ms/step - loss: 0.0011
# Epoch 97/100
# 1/1 [==============================] - 0s 181ms/step - loss: 9.3026e-04
# Epoch 98/100
# 1/1 [==============================] - 0s 199ms/step - loss: 9.2391e-04
# Epoch 99/100
# 1/1 [==============================] - 0s 177ms/step - loss: 0.0011
# Epoch 100/100
# 1/1 [==============================] - 0s 200ms/step - loss: 0.0013

# %%
print(model.evaluate(X, Y, batch_size=1))
output = model.predict(X)
output *= 128
# Output colorizations
cur = np.zeros((400, 400, 3))
cur[:,:,0] = X[0][:,:,0]
cur[:,:,1:] = output[0]
imsave("img_result.png", lab2rgb(cur))
imsave("img_gray_version.png", rgb2gray(lab2rgb(cur)))
# Out:
# 1/1 [==============================] - 0s 77ms/step
# 0.0015809491742402315
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
